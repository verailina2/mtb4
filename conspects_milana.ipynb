# %% [markdown]
# # Настройка GIT
# * настроим ник и email
# * получить токен github

# %%
# !git config --global user.name "lamilans"
# !git config --global user.email "llamilka@yandex.ru"

# %% [markdown]
# Перейдем в папку Colab Notebook

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# Стянем репозиторий к себе на диск

# %%
# !git clone https://github.com/verailina2/mtb4.git
# Out:
# fatal: destination path 'mtb4' already exists and is not an empty directory.

# %%
# !mv conspects_milana.ipynb mtb4/
# Out:
# mv: cannot stat 'conspects_milana.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/mtb4
# Out:
# /content/drive/MyDrive/Colab Notebooks/mtb4

# %% [markdown]
# # Передадим файл в репозиторий

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "Добавила новый текст"
# Out:
# [main d7df035] Добавила новый текст
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite conspects_milana.ipynb (63%)

# %%
token = "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"
username = "verailina2"
repo = "mtb4"

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/verailina2/mtb4.git (fetch)
# origin	https://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@github.com/verailina2/mtb4.git (push)

# %%
# !git push origin main
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 2.40 KiB | 111.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/verailina2/mtb4.git
#    41bab93..d7df035  main -> main

# %%
# !git pull origin main
# Out:
# From https://github.com/verailina2/mtb4
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # Журнал коммитов - log

# %%
# !git log
# Out:
# commit d7df0358267e22eca8711e7aba1d96f0486db673 (HEAD -> main, origin/main, origin/HEAD)
# Author: lamilans <llamilka@yandex.ru>
# Date:   Tue Feb 21 18:48:39 2023 +0000
#
#     Добавила новый текст
#
# commit 7211bcc6f7245061aca5399ace4fcf8ebed642ce
# Author: lamilans <llamilka@yandex.ru>
# Date:   Tue Feb 21 16:14:19 2023 +0000
#
#     Добавила новый текст
#
# commit 41bab93977b6b03a0ca2f04f3fd1729c9253852e
# Author: lamilans <llamilka@yandex.ru>
# Date:   Tue Feb 21 14:18:26 2023 +0000
#
#     Добавила новый текст
#
# commit 833e370e96b4892a64411b763e60e82d27149c30
# Author: lamilans <llamilka@yandex.ru>
# Date:   Tue Feb 21 14:16:12 2023 +0000
#
#     Добавила новый текст
#
# commit 6f0fff710fc7fdccb07d48fa7844d2bcedacd11b
# Author: lamilans <llamilka@yandex.ru>
# Date:   Tue Feb 21 14:15:32 2023 +0000
#
#     Добавила новый текст
#
# commit 3658b866e2b22cdb7879173fa3bdefb0463a7f11
# Author: Nikita Pyshkov <85805562+pyshkovni@users.noreply.github.com>
# ...

# %%
# !git log --oneline
# Out:
# d7df035 (HEAD -> main, origin/main, origin/HEAD) Добавила новый текст
# 7211bcc Добавила новый текст
# 41bab93 Добавила новый текст
# 833e370 Добавила новый текст
# 6f0fff7 Добавила новый текст
# 3658b86 Пункт 2 Замечания про работу в команде!
# 74626f4 Добавил замечания
# e592a69 (origin/master) Сделал зону для коммитов
# 5a93936 Добавила файл conspects_IlinaVera.ipynb
# 32450b8 Добавила файл conspects_IlinaVera.ipynb
# 7b69a0f Добавила файл conspects_IlinaVera.ipynb
# fa7daba Добавил раздел log
# 98f1f7b Добавила файл conspects_IlinaVera.ipynb
# dd1e6a1 Добавил текст
# 94b7f00 Добавил файл в репозиторий
# 7954334 Добавил файл в репозиторий
# 6cff53c Delete conspects_EzhovkinaJ.ipynb
# 7eda383 Delete conspects_EzhovkinaYu.ipynb
# eba50e4 Добавила файл conspects_IlinaVera.ipynb
# 4af9583 Изменила свой файл
# 80ce0c1 Изменила свой файл
# 1d98cde Добавил текст
# cb49cd1 Добавил текст
# 9149034 Delete conspects_EzhovkinaJ.ipynb
# dd090c3 Добавил свой файл
# 6983da6 Добавил текст
# ...
