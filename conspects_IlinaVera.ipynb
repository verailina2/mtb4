# %%
pwd
# Out:
# '/content'

# %% [markdown]
# Код выше написан на языке Python

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим имя и email
# * получить токен от github

# %%
# !git config --global user.name "verailina2"
# !git config --global user.email "vera.ilina.98@bk.ru"
# !git config --global user.password "verakiparis3415"

# %%
token = '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'
username = 'verailina2'
repo = 'mtb4'

# %% [markdown]
# Перейдем в папку и подключимся к диску

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'mtb4'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 158 (delta 86), reused 142 (delta 73), pack-reused 0
# Receiving objects: 100% (158/158), 75.70 KiB | 1.76 MiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# !mv conspects_IlinaVera.ipynb mtb4/

# %%
cd /content/drive/MyDrive/Colab Notebooks/mtb4
# Out:
# /content/drive/MyDrive/Colab Notebooks/mtb4

# %% [markdown]
# # Математика Python

# %% [markdown]
# #Передадим файл в репозиторий

# %%
# !git status
