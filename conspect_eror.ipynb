# %%
pwd
# Out:
# '/content'

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим ник и email
# * получить токен github

# %%
# !git config --global user.name "yujlia"
# !git config --global user.email "yulia.ezhovkina@yandex.ru"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Перейдем в папку  Colab Notebook

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# Стянем репозеторий к себе на диск.

# %%
# !git clone https://github.com/verailina2/mtb4.git
# Out:
# fatal: destination path 'mtb4' already exists and is not an empty directory.

# %%
# !mv conspects_EzhovkinaYu.ipynb mtb4/
# Out:
# mv: cannot stat 'conspects_EzhovkinaYu.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/mtb4
# Out:
# /content/drive/MyDrive/Colab Notebooks/mtb4

# %% [markdown]
# #Математика Pythone
# 1.Какие математические операции можно проводить с числами Phiton?
# 2.Приведите примеры и найдите 3 отличия от классической математики. Используйте ячейки кода и текста в Google Colab

# %% [markdown]
# #1.
# ##Математические операции.

# %% [markdown]
# ##1.Сложение

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ##2. Вычитание

# %%
176 - 34
# Out:
# 142

# %% [markdown]
# ##3.Умножение

# %%
271 * 27
# Out:
# 7317

# %% [markdown]
# ##4.Деление

# %%
356 / 5
# Out:
# 71.2

# %% [markdown]
# ##5.Полученеи целой части от деление
# (целочисленное деление)

# %%
356 // 5
# Out:
# 71

# %% [markdown]
# ##6.Остаток от деления

# %%
365 % 7
# Out:
# 1

# %% [markdown]
# ##7.Возведение в степень

# %%
13 ** 3
# Out:
# 2197

# %% [markdown]
# #Три отличия от обычной математики.

# %% [markdown]
# #1.Работа с комплексными числами.
# ### Комплексные числа можно складывать, вычитать, умножать, делить и возводить в степень. Для создания комплексного числа можно использовать функцию complex(a,b), в которую, в качестве первого аргумента, передается действительная часть, а в качестве второго - минимальная. Либо записать как a + bj.

# %%
z = 1 + 2j
print (z)
# Out:
# (1+2j)

# %%
x = complex(3, 2)
print (x)
# Out:
# (3+2j)

# %%
x + z
# Out:
# (4+4j)

# %% [markdown]
# #2.Битовые операции.
# ###В Python доступны битовые операции, их можно производить над целыми числами.

# %%
p = 9
q = 3
p & q
# Out:
# 1

# %%
p | q
# Out:
# 11

# %%
p ^ q
# Out:
# 10

# %% [markdown]
# #3.Представление чисел в других системах счисления.
# ###В своей повседневной жизни мы используем десятичную систему исчисления, но при программировании, очень часто, приходиться работать с 16й, 2ой,8ой.

# %%
m = 123453
hex(m)
# Out:
# '0x1e23d'

# %% [markdown]
# Представление в шестнадцатиричной.

# %%
oct(m)
# Out:
# '0o361075'

# %% [markdown]
# В восьмиричной

# %%
bin(m)
# Out:
# '0b11110001000111101'

# %% [markdown]
# в двоичной

# %% [markdown]
# #Передaдим файл в репозиторий.

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 3 commits.
#   (use "git push" to publish your local commits)
#
# It took 2.25 seconds to compute the branch ahead/behind values.
# You can use '--no-ahead-behind' to avoid this.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m 'Добавил свой файл от себя.'
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 3 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
token = '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'
username = 'verailina2'
repo = 'mtb4'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/verailina2/mtb4 (fetch)
# origin	https://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@github.com/verailina2/mtb4 (push)

# %%
# !git push origin master
# Out:
# To https://github.com/verailina2/mtb4
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://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@github.com/verailina2/mtb4'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %% [markdown]
# #Зона для коммитов
# * смотрим статус
# * добавляем файлы в отслеживаемые
# * оставляем коммит (напиши сообщение сам)
# * Пушим на сервер

# %%
# !git add .
# !git commit -m 'Сделал зону для коммитов'
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 3 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push original master
# Out:
# fatal: 'original' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git puii origin master
# Out:
# git: 'puii' is not a git command. See 'git --help'.
#
# The most similar commands are
# 	pull
# 	push
