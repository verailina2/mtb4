# %% [markdown]
# # Настройка Git
# *   Настроим Ник и email
# *   Получить токен GitHub

# %%
! git config --global user.name "lizobakted"
! git config --global user.email "lizobakt.ed@yandex.ru"

# %%
token = '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'
username = 'verailina2'
repo = 'mtb4'

# %% [markdown]
# Перейдем в папку Colab Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# Стянем репозиторий к себе на диск

# %%
! git clone https://github.com/verailina2/mtb4.git
# Out:
# fatal: destination path 'mtb4' already exists and is not an empty directory.

# %%
! mv conspects_Kharitonova.ipynb mtb4/
# Out:
# mv: cannot stat 'conspects_Kharitonova.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/mtb4
# Out:
# /content/drive/MyDrive/Colab Notebooks/mtb4

# %% [markdown]
# # Математика Python

# %% [markdown]
# 1.   Какие математические операции можно производить с числами в Python?
# 2.   Приведите примеры и найдите 3 отличия от классической математики. Используйте ячейки кода и текста в Google Colab

# %% [markdown]
# ## В Python можно производить следующие математические операции с числами:

# %% [markdown]
# ### Сложение (+)

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# ### Вычитание (-)

# %%
5 - 2
# Out:
# 3

# %% [markdown]
# ### Умножение (*)

# %%
3 * 4
# Out:
# 12

# %% [markdown]
# ### Деление (/)

# %%
10 / 2
# Out:
# 5.0

# %% [markdown]
# ### Целочисленное деление (//)

# %%
10 // 3
# Out:
# 3

# %% [markdown]
# ### Остаток от деления (%)

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# ### Возведение в степень (**)

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ## 3 отличия от классической математики

# %% [markdown]
# ### Python позволяет выполнять разные математические вычисления, но он имеет некоторые отличия от классической математики.

# %% [markdown]
# ### 1. Python использует числа с плавающей точкой для представления действительных чисел, в то время как классическая математика использует десятичные дроби или несократимые дроби. Стоит уделять внимание тому, какие типы деления и округления используются в коде, так как это может привести к неточностям в вычислениях в Python.

# %% [markdown]
# ### Типы округления:

# %% [markdown]
# int() Округляет число в сторону нуля

# %%
int(4.65678)
# Out:
# 4

# %% [markdown]
# round(x)  Округляет число x до ближайшего целого. Если дробная часть числа равна 0.5, то число округляется до ближайшего четного числа

# %%
round(3.987)
# Out:
# 4

# %% [markdown]
# round(x, n) Округляет число x до n знаков после точки

# %%
round(5.98765, 3)
# Out:
# 5.988

# %% [markdown]
# floor(x)  Округляет число x вниз («пол»)

# %%
import math
math.floor(7.45678)
# Out:
# 7

# %% [markdown]
# ceil(x) Округляет число x вверх («потолок»)

# %%
import math
math.ceil(7.45678)
# Out:
# 8

# %% [markdown]
# abs(x)  Модуль числа x (абсолютная величина)

# %%
abs(7.45678)
# Out:
# 7.45678

# %% [markdown]
# ### Типы деления (см. примеры выше):
#
#
# * Деление (/)
# * Целочисленное деление (//)
# * Остаток от деления (%)

# %% [markdown]
# ### 2. Python предлагает дополнительные возможности, такие как математические библиотеки, которые недоступны в классической математике. Эти возможности можно активировать при помощи модуля math. (например sqrt(x); pow(x, n); degrees(x); cos(x) и т. д.)

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
import math
math.pow(9, 2)
# Out:
# 81.0

# %%
import math
math.degrees(1)
# Out:
# 57.29577951308232

# %%
import math
math.cos(1)
# Out:
# 0.5403023058681398

# %% [markdown]
# ### 3. Типы данных: в Python существует разные типы данных для чисел, такие как int, float и complex, в то время как в классической математике мы используем в основном действительные и комплексные числа.

# %% [markdown]
# # Передадим файлы в репозиторий

# %%
! git status

# %%
! git add .

# %%
! git commit -m 'Изменила свой файл'

# %%
! git push origin master

# %% [markdown]
# # Зона для коммитов
# *   смотрим статус
# *   генерируем новый токен (при необходимости)
# *   обновляем ссылку
# *   делаем пулл
# *   добавляем файмы в отслеживаемые
# *   оставляем коммит (напиши сообщение сам)
# *   пушим на сервер

# %%
token = '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'
username = 'verailina2'
repo = 'mtb4'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
! git remote -v
# Out:
# origin	https://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@github.com/verailina2/mtb4.git (fetch)
# origin	https://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@github.com/verailina2/mtb4.git (push)

# %%
! git add .
! git commit -m 'Удалила файлы с ветки Kharitonova'
# Out:
# [Kharitonova facd785] Удалила файлы с ветки Kharitonova
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
! git push origin Kharitonova
# Out:
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1.61 KiB | 164.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# To https://github.com/verailina2/mtb4.git
#    7e4df1d..facd785  Kharitonova -> Kharitonova

# %%
! git pull origin Kharitonova

# %%
! git checkout conspects_Kharitonova.ipynb
# Out:
# Updated 1 path from the index

# %% [markdown]
# # Push на master

# %%
! git push origin master

# %%
! git pull origin master

# %%
! git fetch --all

# %% [markdown]
# # Журнал коммитов - log

# %%
! git log

# %%
! git log --oneline

# %% [markdown]
# # Ветвление в Git

# %%
! git branch

# %%
! git checkout -b Kharitonova

# %%
! git checkout master

# %%
! git branch -M main
